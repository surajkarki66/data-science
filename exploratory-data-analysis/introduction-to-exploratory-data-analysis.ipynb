# %% [markdown]
# # Introduction to Exploratory Data Analysis
# In this notebook, we gonna learn how we can perform exploratory data analysis on a given dataset.

# %% [markdown]
# ## Step 1: Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns


plt.style.use('ggplot')
#pd.set_option('max_columns', 200)

# %% [markdown]
# ## Step 2: Loading Data

# %%
df = pd.read_csv('./coaster_db.csv')

# %% [markdown]
# ## Step 3: Data Understanding
# We need to first grasp the fundamental understanding of the data. Such as
# - Dataset shape
# - Dataset head and tail
# - Dataset type dtypes
# - Dataset Description

# %%
df.shape # shape of dataframe
# Out:
# (1087, 57)

# %%
df.head(5) # Top-5 rows from dataframe
# Out:
#    Unnamed: 0                            coaster_name          Length  \
# 0           0                      Switchback Railway  600 ft (180 m)
# 1           1                       Flip Flap Railway             NaN
# 2           2  Switchback Railway (Euclid Beach Park)             NaN
# 3           3            Loop the Loop (Coney Island)             NaN
# 4           4            Loop the Loop (Young's Pier)             NaN
#
#               Speed                        Location   Status   Opening date  \
# 0  6 mph (9.7 km/h)                    Coney Island  Removed  June 16, 1884
# 1               NaN                   Sea Lion Park  Removed           1895
# 2               NaN  Cleveland, Ohio, United States   Closed            NaN
# 3               NaN                           Other  Removed           1901
# 4               NaN                           Other  Removed           1901
#
#     Type            Manufacturer Height restriction  ...  speed1    speed2  \
# 0   Wood  LaMarcus Adna Thompson                NaN  ...  6 mph   9.7 km/h
# 1   Wood            Lina Beecher                NaN  ...     NaN       NaN
# 2  Other                     NaN                NaN  ...     NaN       NaN
# 3  Steel          Edwin Prescott                NaN  ...     NaN       NaN
# 4  Steel          Edwin Prescott                NaN  ...     NaN       NaN
#
#    speed1_value speed1_unit speed_mph height_value height_unit height_ft  \
# 0           6.0         mph       6.0         50.0          ft       NaN
# 1           NaN         NaN       NaN          NaN         NaN       NaN
# 2           NaN         NaN       NaN          NaN         NaN       NaN
# 3           NaN         NaN       NaN          NaN         NaN       NaN
# 4           NaN         NaN       NaN          NaN         NaN       NaN
#
#   Inversions_clean Gforce_clean
# 0                0          2.9
# 1                1         12.0
# 2                0          NaN
# 3                1          NaN
# 4                1          NaN
#
# [5 rows x 57 columns]

# %%
df.columns # listing all columns of the dataframe
# Out:
# Index(['Unnamed: 0', 'coaster_name', 'Length', 'Speed', 'Location', 'Status',
#        'Opening date', 'Type', 'Manufacturer', 'Height restriction', 'Model',
#        'Height', 'Inversions', 'Lift/launch system', 'Cost', 'Trains',
#        'Park section', 'Duration', 'Capacity', 'G-force', 'Designer',
#        'Max vertical angle', 'Drop', 'Soft opening date',
#        'Fast Lane available', 'Replaced', 'Track layout', 'Fastrack available',
#        'Soft opening date.1', 'Closing date', 'Opened', 'Replaced by',
#        'Website', 'Flash Pass Available', 'Must transfer from wheelchair',
#        'Theme', 'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df.dtypes # list datatypes of each column
# Out:
# Unnamed: 0                         int64
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# Fast Lane available               object
# Replaced                          object
# Track layout                      object
# Fastrack available                object
# Soft opening date.1               object
# Closing date                      object
# Opened                            object
# Replaced by                       object
# Website                           object
# Flash Pass Available              object
# Must transfer from wheelchair     object
# Theme                             object
# Single rider line available       object
# Restraint Style                   object
# Flash Pass available              object
# Acceleration                      object
# Restraints                        object
# Name                              object
# year_introduced                    int64
# latitude                         float64
# longitude                        float64
# Type_Main                         object
# opening_date_clean                object
# speed1                            object
# speed2                            object
# speed1_value                     float64
# speed1_unit                       object
# speed_mph                        float64
# height_value                     float64
# height_unit                       object
# height_ft                        float64
# Inversions_clean                   int64
# Gforce_clean                     float64
# dtype: object

# %%
df.describe() #statistical description
# Out:
#         Unnamed: 0  Inversions  year_introduced    latitude   longitude  \
# count  1087.000000  932.000000      1087.000000  812.000000  812.000000
# mean    543.000000    1.547210      1994.986201   38.373484  -41.595373
# std     313.934176    2.114073        23.475248   15.516596   72.285227
# min       0.000000    0.000000      1884.000000  -48.261700 -123.035700
# 25%     271.500000    0.000000      1989.000000   35.031050  -84.552200
# 50%     543.000000    0.000000      2000.000000   40.289800  -76.653600
# 75%     814.500000    3.000000      2010.000000   44.799600    2.778100
# max    1086.000000   14.000000      2022.000000   63.230900  153.426500
#
#        speed1_value   speed_mph  height_value   height_ft  Inversions_clean  \
# count    937.000000  937.000000    965.000000  171.000000       1087.000000
# mean      53.850374   48.617289     89.575171  101.996491          1.326587
# std       23.385518   16.678031    136.246444   67.329092          2.030854
# min        5.000000    5.000000      4.000000   13.100000          0.000000
# 25%       40.000000   37.300000     44.000000   51.800000          0.000000
# 50%       50.000000   49.700000     79.000000   91.200000          0.000000
# 75%       63.000000   58.000000    113.000000  131.200000          2.000000
# max      240.000000  149.100000   3937.000000  377.300000         14.000000
#
#        Gforce_clean
# count    362.000000
# mean       3.824006
# std        0.989998
# min        0.800000
# 25%        3.400000
# 50%        4.000000
# 75%        4.500000
# max       12.000000

# %% [markdown]
# ## Step 4: Data Preperation
# Before start to anaylze the data, we have to make sure that the data is cleaned. Following steps will be performed during data preparation.
# - Dropping irrelevant columns and rows
# - Identifying duplicated columns
# - Renaming Columns
# - Feature Creation

# %%
# Example of dropping columns
# df.drop(['Opening date'], axis=1)

# %%
# removing columns
df = df[['coaster_name',
    # 'Length', 'Speed',
    'Location', 'Status',
    # 'Opening date',
    #   'Type',
    'Manufacturer',
#     'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date',
#     'Opened', 
    # 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
        'latitude', 'longitude',
    'Type_Main',
       'opening_date_clean',
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit',
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.head(5)
# Out:
#                              coaster_name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  year_introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main opening_date_clean  speed_mph  height_ft  Inversions_clean  \
# 0      Wood         1884-06-16        6.0        NaN                 0
# 1      Wood         1895-01-01        NaN        NaN                 1
# 2     Other                NaN        NaN        NaN                 0
# 3     Steel         1901-01-01        NaN        NaN                 1
# 4     Steel         1901-01-01        NaN        NaN                 1
#
#    Gforce_clean
# 0           2.9
# 1          12.0
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# converting the string date to a datetime date
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
# Rename our columns
df = df.rename(columns={'coaster_name':'Coaster_Name',
                   'year_introduced':'Year_Introduced',
                   'opening_date_clean':'Opening_Date',
                   'speed_mph':'Speed_mph',
                   'height_ft':'Height_ft',
                   'Inversions_clean':'Inversions',
                   'Gforce_clean':'Gforce'})

# %%
# Shows which column have how many null values?
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# latitude           275
# longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_mph          150
# Height_ft          916
# Inversions           0
# Gforce             725
# dtype: int64

# %%
# Show duplicate rows: it only return rows which have all duplicate column values.
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, latitude, longitude, Type_Main, Opening_Date, Speed_mph, Height_ft, Inversions, Gforce]
# Index: []

# %%
# Check for duplicate coaster name: It show rows that have duplicate coaster name.
df.loc[df.duplicated(subset=['Coaster_Name'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# 43               Removed                                 Traver Engineering
# 60               Removed                                     Fred W. Pearce
# 61                Closed                                                NaN
# 167                  NaN  Arrow Development (California and Florida)Dyna...
# 237            Operating                                         Mack Rides
# ...                  ...                                                ...
# 1063           Operating                                           Zamperla
# 1064           Operating                            Allan Herschell Company
# 1080  Under construction                        Rocky Mountain Construction
# 1082                 NaN                                  Anton Schwarzkopf
# 1084                 NaN                                             Vekoma
#
#       Year_Introduced  latitude  longitude Type_Main Opening_Date  Speed_mph  \
# 43               1927   42.8617   -79.0598      Wood   1926-01-01       60.0
# 60               1937   42.4200   -70.9860      Wood   1911-01-01        NaN
# 61               1938   41.6349   -80.3180      Wood   1938-05-23       50.0
# 167              1980       NaN        NaN     Steel          NaT       35.0
# 237              1986   43.8427   -79.5423     Steel   1981-05-23       39.8
# ...               ...       ...        ...       ...          ...        ...
# 1063             2021   40.1343   -74.4434     Steel   1999-01-01        NaN
# 1064             2021   41.6343   -80.3165     Steel   1950-01-01        NaN
# 1080             2022   28.0339   -82.4231     Steel          NaT       76.0
# 1082             2022       NaN        NaN     Steel          NaT       53.0
# 1084             2022       NaN        NaN     Steel   2016-06-16       59.3
#
#       Height_ft  Inversions  Gforce
# 43          NaN           0     4.0
# 60          NaN           0     NaN
# 61          NaN           0     NaN
# 167         NaN           0     NaN
# 237        32.8           0     NaN
# ...         ...         ...     ...
# 1063        NaN           0     NaN
# 1064        NaN           0     NaN
# 1080        NaN           2     NaN
# 1082        NaN           3     4.7
# 1084        NaN           0     4.0
#
# [97 rows x 13 columns]

# %%
# Checking an example duplicate
df.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  latitude  longitude Type_Main Opening_Date  Speed_mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_ft  Inversions  Gforce
# 39        NaN           0     4.0
# 43        NaN           0     4.0

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening_Date', 'Speed_mph',
#        'Height_ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date']).sum()
# Out:
# 97

# %%
# select just columns that are not the duplicate so just the first version.
# reset index is done in order to put index value in order
df = df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])] \
    .reset_index(drop=True).copy()

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date  Speed_mph  Height_ft  Inversions  Gforce
# 0      Wood   1884-06-16        6.0        NaN           0     2.9
# 1      Wood   1895-01-01        NaN        NaN           1    12.0
# 2     Other          NaT        NaN        NaN           0     NaN
# 3     Steel   1901-01-01        NaN        NaN           1     NaN
# 4     Steel   1901-01-01        NaN        NaN           1     NaN

# %%
df.shape
# Out:
# (990, 13)

# %%
# we removed all rows that contains nan value.
# another better approach would be replacing the nan values with some other values
df = df.dropna().reset_index(drop=True).copy()
df.head()
# Out:
#               Coaster_Name        Location  \
# 0        Python (Efteling)        Efteling
# 1  Mindbender (Galaxyland)      Galaxyland
# 2            Lisebergbanan        Liseberg
# 3                 Goudurix    Parc Astérix
# 4  Condor (roller coaster)  Walibi Holland
#
#                                               Status       Manufacturer  \
# 0                                          Operating             Vekoma
# 1  closed for maintenance as of july 30 no reopen...  Anton Schwarzkopf
# 2                                          Operating             Zierer
# 3                                          Operating             Vekoma
# 4                                          Operating             Vekoma
#
#    Year_Introduced  latitude  longitude Type_Main Opening_Date  Speed_mph  \
# 0             1981   51.6469     5.0536     Steel   1981-04-12       46.6
# 1             1985   53.5236  -113.6203     Steel   1985-12-20       60.0
# 2             1987   57.6950    11.9925     Steel   1987-04-18       49.7
# 3             1989   49.1314     2.5714     Steel   1989-01-01       55.9
# 4             1994   52.4404     5.7615     Steel   1994-05-01       49.7
#
#    Height_ft  Inversions  Gforce
# 0       95.1           4     3.5
# 1      145.0           3     5.2
# 2      147.6           0     3.0
# 3      118.1           7     3.9
# 4      101.7           5     4.5

# %%
df.shape
# Out:
# (60, 13)

# %% [markdown]
# # Step 5: Feature Understanding
# Univariate analysis: Looking each feature individually.
# - Plotting Feature Distributions
#     - Histogram
#     - KDE
#     - Boxplot

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 2002    5
# 2014    4
# 2012    4
# 2009    4
# 2008    4
# 2011    4
# 1994    3
# 2004    3
# 2013    3
# 2007    3
# 2016    2
# 1998    2
# 1995    2
# 2003    2
# 2010    2
# 2005    2
# 2015    1
# 2017    1
# 2019    1
# 1981    1
# 1985    1
# 2001    1
# 2000    1
# 1997    1
# 1989    1
# 1987    1
# 2020    1
# Name: count, dtype: int64

# %%
ax = df['Year_Introduced'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Top 10 Years Coasters Introduced')
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# for continuous value like speed it would be better to plot the histogram to get better idea of distribution.
ax = df['Speed_mph'].plot(kind='hist',
                          bins=20,
                          title='Coaster Speed (mph)')
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
ax = df['Speed_mph'].plot(kind='kde',
                          title='Coaster Speed (mph)')
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
df['Type_Main'].value_counts()
# Out:
# Type_Main
# Steel    56
# Wood      2
# Other     2
# Name: count, dtype: int64

# %% [markdown]
# ## Step 6: Feature Relationships
# In this step, we gonna see the relationship between features.
# - Scatterplot
# - Heatmap Correlation
# - Pairplot
# - Groupby comparisons

# %%
df.plot(kind='scatter',
        x='Speed_mph',
        y='Height_ft',
        title='Coaster Speed vs. Height')
plt.show()

# %%
ax = sns.scatterplot(x='Speed_mph',
                y='Height_ft',
                hue='Year_Introduced',
                data=df)
ax.set_title('Coaster Speed vs. Height')
plt.show()

# %%
sns.pairplot(df,
             vars=['Year_Introduced','Speed_mph',
                   'Height_ft','Inversions','Gforce'],
            hue='Type_Main')
plt.show()
# Out:
# /home/surajkarki/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Showing correlation between features
df_corr = df[['Year_Introduced','Speed_mph',
    'Height_ft','Inversions','Gforce']].corr()
df_corr
# Out:
#                  Year_Introduced  Speed_mph  Height_ft  Inversions    Gforce
# Year_Introduced         1.000000   0.113510   0.082382   -0.252572  0.120494
# Speed_mph               0.113510   1.000000   0.717000   -0.031512  0.613343
# Height_ft               0.082382   0.717000   1.000000   -0.079763  0.451928
# Inversions             -0.252572  -0.031512  -0.079763    1.000000  0.294836
# Gforce                  0.120494   0.613343   0.451928    0.294836  1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Step 7: Ask a Question about the data
# Tough step
# - Try to answer a question you have about the data using a plot or statistic.
#
# What are the locations with the fastest roller coasters?

# %%
ax = df.query('Location != "Other"') \
    .groupby('Location')['Speed_mph'] \
    .agg(['mean','count']) \
    .sort_values('mean')['mean'] \
    .plot(kind='barh', figsize=(12, 5), title='Average Coast Speed by Location')
ax.set_xlabel('Average Coaster Speed')
plt.show()
