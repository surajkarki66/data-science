# %%
# sorting
import numpy as np

# %%
arr = np.random.randn(10, 10)

# %%
indexer = np.argsort(arr)
indexer
# Out:
# array([[3, 9, 1, 6, 4, 8, 0, 7, 2, 5],
#        [7, 8, 9, 1, 4, 2, 3, 0, 6, 5],
#        [5, 8, 3, 7, 1, 0, 4, 2, 6, 9],
#        [8, 4, 3, 1, 9, 6, 2, 5, 7, 0],
#        [9, 4, 8, 2, 5, 1, 3, 7, 0, 6],
#        [8, 0, 5, 2, 4, 3, 7, 9, 1, 6],
#        [9, 7, 3, 5, 1, 0, 4, 6, 2, 8],
#        [0, 2, 1, 4, 3, 9, 5, 6, 8, 7],
#        [2, 8, 9, 7, 5, 1, 6, 3, 0, 4],
#        [3, 5, 2, 1, 9, 7, 6, 8, 0, 4]])

# %%
arr[indexer]
# Out:
# array([[[ 2.88522095, -0.38274079,  0.50009981, -0.58281974,
#          -0.88076293,  0.65313191, -0.25863274,  0.89113792,
#          -1.37445146, -0.36698475],
#         [ 0.66072864, -0.53682459, -0.97340603, -1.901318  ,
#           0.7197173 , -1.07457718,  0.12728566, -0.03202173,
#           0.4088212 , -0.11084677],
#         [ 1.09577501, -0.45079943,  0.24452827,  0.90285281,
#           0.08979038,  1.6387397 ,  1.60391704, -1.87989014,
#          -1.65173241, -1.46466561],
#         [-0.22258923, -0.34656862,  0.47251801, -1.70833707,
#           0.10524797, -0.57078688,  0.4535009 , -2.18390753,
#           1.15068185, -3.45349576],
#         [ 1.2456279 ,  0.01054191, -0.95798339,  0.73222058,
#          -1.35492593, -0.81242436,  1.71577498,  0.93838066,
#          -1.19012309, -2.54230932],
#         [ 1.11708327,  0.04705634, -1.95113993,  0.40344252,
#           2.43971015, -0.2440005 ,  0.38396645, -0.68339302,
#          -1.90870993, -1.3563403 ],
# ...
